# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import pandas as pd

# %%
# train.csv 파일 불러보기
train= pd.read_csv('train.csv', index_col='PassengerId')

# %%
# 데이터프레임에서 위에서부터 5개 정보
train.head (3) #꼬리에 있는건 tail
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S

# %%
# 데이터프레임에서 아래에서부터 5개 정보
train.tail(3)
# Out:
#              Survived  Pclass                                      Name  \
# PassengerId
# 889                 0       3  Johnston, Miss. Catherine Helen "Carrie"
# 890                 1       1                     Behr, Mr. Karl Howell
# 891                 0       3                       Dooley, Mr. Patrick
#
#                 Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# PassengerId
# 889          female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 890            male  26.0      0      0      111369  30.00  C148        C
# 891            male  32.0      0      0      370376   7.75   NaN        Q

# %%
# 각 컬럼별 데이터 갯수 확인
train.count()
# Out:
# Survived    891
# Pclass      891
# Name        891
# Sex         891
# Age         714
# SibSp       891
# Parch       891
# Ticket      891
# Fare        891
# Cabin       204
# Embarked    889
# dtype: int64

# %%
# 결측치 확인하기
train.isnull().sum()
#sibsp - 형제자매 배우자
#parch - 부모,자식
#cabin - 객실번호
#embarke - 어디서 탔냐?
# Out:
# Survived      0
# Pclass        0
# Name          0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Ticket        0
# Fare          0
# Cabin       687
# Embarked      2
# dtype: int64

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# 성별에 따른 인원수
# train.value_counts('Sex')
train['Sex'].value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
# 객실 등급에 따른 인원수
train['Pclass'].value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %%
# 사망/생존에 따른 인원수
train['Survived'].value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
# 나이에 따른 인원수
train.value_counts('Age')
# Out:
# Age
# 24.00    30
# 22.00    27
# 18.00    26
# 30.00    25
# 28.00    25
#          ..
# 20.50     1
# 14.50     1
# 12.00     1
# 0.92      1
# 80.00     1
# Length: 88, dtype: int64

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-3.png](attachment:image-3.png)

# %%
# 카테고리
ages = [1, 2, 10, 21, 23, 37, 31, 61, 20, 41, 32, 99]
bins = [0, 15, 25, 35, 60, 99]
labels = ["미성년자", "청년", "중년", "장년", "노년"]
cats=pd.cut(ages,bins,labels=labels)
# pd.cut(데이터, 범위, 라벨)

# %%
cats
# 0살부터라고 하면 0살 포함안되!! 0살 초과부터!! bin을 -1로 해주자??
# Out:
# ['미성년자', '미성년자', '미성년자', '청년', '청년', ..., '노년', '청년', '장년', '중년', '노년']
# Length: 12
# Categories (5, object): ['미성년자' < '청년' < '중년' < '장년' < '노년']

# %%
ageArr = pd.DataFrame(ages, columns=['ages'])

# %%
ageArr
# Out:
#             ages cats
# PassengerId
# 1            NaN   청년
# 2            NaN   장년
# 3            NaN   중년
# 4            NaN   중년
# 5            NaN   중년
# ...          ...  ...
# 887          NaN   중년
# 888          NaN   청년
# 889          NaN  NaN
# 890          NaN   중년
# 891          NaN   중년
#
# [891 rows x 2 columns]

# %%
# ages 데이터 프레임에 cats컬럼 추가
ageArr['cats'] = cats

# %%
ageArr['cats']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'cats'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-6-f83142844caf> in <module>
# ----> 1 ageArr['cats']
#
# ...

# %%
ageArr['cats'].value_counts()
# cats.value_counts()
# Out:
# 미성년자    3
# 청년      3
# 중년      2
# 장년      2
# 노년      2
# Name: cats, dtype: int64

# %%
train
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   1       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   1       3
# ...               ...     ...
# 887                 1       2
# 888                 1       1
# 889                 1       3
# 890                 1       1
# 891                 1       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %%
# 카테고리
ages = train['Age']
bins = [-1, 15, 25, 35, 60, 99]
labels = ["미성년자", "청년", "중년", "장년", "노년"]
cats=pd.cut(ages,bins,labels=labels)

# %%
train['Cats'] = cats

# %%
train.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked Cats
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S   청년
# 2                1      0          PC 17599  71.2833   C85        C   장년
# ...

# %%
family=train['SibSp']+train['Parch']
train['family'] = family

# %%
family
# Out:
# PassengerId
# 1      1
# 2      1
# 3      0
# 4      1
# 5      0
#       ..
# 887    0
# 888    0
# 889    3
# 890    0
# 891    0
# Length: 891, dtype: int64

# %%
train['Cats'].value_counts()
# Out:
# 청년      218
# 중년      196
# 장년      195
# 미성년자     83
# 노년       22
# Name: Cats, dtype: int64

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
train['Survived']==0
# Out:
# PassengerId
# 1       True
# 2      False
# 3      False
# 4      False
# 5       True
#        ...
# 887     True
# 888    False
# 889     True
# 890    False
# 891     True
# Name: Survived, Length: 891, dtype: bool

# %%
Survived_0=train[train['Survived']==0]
Survived_0
# Out:
#              Survived  Pclass                                      Name  \
# PassengerId
# 1                   0       3                   Braund, Mr. Owen Harris
# 5                   0       3                  Allen, Mr. William Henry
# 6                   0       3                          Moran, Mr. James
# 7                   0       1                   McCarthy, Mr. Timothy J
# 8                   0       3            Palsson, Master. Gosta Leonard
# ...               ...     ...                                       ...
# 885                 0       3                    Sutehall, Mr. Henry Jr
# 886                 0       3      Rice, Mrs. William (Margaret Norton)
# 887                 0       2                     Montvila, Rev. Juozas
# 889                 0       3  Johnston, Miss. Catherine Helen "Carrie"
# 891                 0       3                       Dooley, Mr. Patrick
#
#                 Sex   Age  SibSp  Parch           Ticket     Fare Cabin  \
# PassengerId
# ...

# %%
Survived_1=train[train['Survived']==1]
Survived_1
# Out:
#              Survived  Pclass  \
# PassengerId
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 9                   1       3
# 10                  1       2
# ...               ...     ...
# 876                 1       3
# 880                 1       1
# 881                 1       2
# 888                 1       1
# 890                 1       1
#
#                                                           Name     Sex   Age  \
# PassengerId
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 9            Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0
# 10                         Nasser, Mrs. Nicholas (Adele Achem)  female  14.0
# ...                                                        ...     ...   ...
# ...

# %%
Survived_1['Cats'].value_counts()
# Out:
# 중년      83
# 장년      78
# 청년      75
# 미성년자    49
# 노년       5
# Name: Cats, dtype: int64

# %%
Survived_1['Cats'].value_counts().sum()
# Out:
# 290

# %%
Survived_1['Cats'].value_counts()/Survived_1['Cats'].value_counts().sum()
# Out:
# 중년      0.286207
# 장년      0.268966
# 청년      0.258621
# 미성년자    0.168966
# 노년      0.017241
# Name: Cats, dtype: float64

# %%
Survived_0['Cats'].value_counts()/Survived_0['Cats'].value_counts().sum()
# Out:
# 청년      0.337264
# 장년      0.275943
# 중년      0.266509
# 미성년자    0.080189
# 노년      0.040094
# Name: Cats, dtype: float64

# %%
train.groupby(['Survived','Cats']).size()/train.groupby(['Survived','Cats']).size().sum()
# Out:
# Survived  Cats
# 0         미성년자    0.047619
#           청년      0.200280
#           중년      0.158263
#           장년      0.163866
#           노년      0.023810
# 1         미성년자    0.068627
#           청년      0.105042
#           중년      0.116246
#           장년      0.109244
#           노년      0.007003
# dtype: float64

# %%
a=train.groupby(['Survived','Cats']).size()
type(a)
# Out:
# pandas.core.series.Series

# %%
a[1].sum()
# Out:
# 290

# %%
a[0].sum()
# Out:
# 424

# %%
a[1]/a[1].sum()
# Out:
# Cats
# 미성년자    0.168966
# 청년      0.258621
# 중년      0.286207
# 장년      0.268966
# 노년      0.017241
# dtype: float64

# %%
a[0]/a[0].sum()
# Out:
# Cats
# 미성년자    0.080189
# 청년      0.337264
# 중년      0.266509
# 장년      0.275943
# 노년      0.040094
# dtype: float64

# %%
#선생님답

# %%
Survived_0=train[train['Survived']==0]
Survived_1=train[train['Survived']==1]

# %%
Survived_0['Cats'].value_counts()/Survived_0['Cats'].value_counts().sum()

# %%
Survived_0['Cats'].value_counts()/Survived_0['Cats'].count()
# Out:
# 청년      0.337264
# 장년      0.275943
# 중년      0.266509
# 미성년자    0.080189
# 노년      0.040094
# Name: Cats, dtype: float64

# %%
Survived_0['Cats'].count()
# Out:
# 424

# %%
Survived_1['Cats'].value_counts()/Survived_1['Cats'].count()

# %%
Survived_1['Cats'].value_counts()/Survived_1['Cats'].value_counts().sum()
# Out:
# 중년      0.286207
# 장년      0.268966
# 청년      0.258621
# 미성년자    0.168966
# 노년      0.017241
# Name: Cats, dtype: float64
