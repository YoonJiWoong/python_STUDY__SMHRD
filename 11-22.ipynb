# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # Numpy
# - 자료형(다차원배열) - 사진, 동영상의 데이터를 다루는데 특화되어있다
# - 효율적인 연산이 가능
# - 딥러닝(3차원이상의 데이터)
#
# # Pandas
# - numpy자료형이 사용됨
# - 1차원, 2차원 자료형이 존재(엑셀 데이터)
# - 깔끔하게 데이터를 표시
# - 머신러닝(1,2차원 데이터)
#
# # Matplotlib
# - 시각화(표로 표시)
# - 머신러닝

# %% [markdown]
# # 1,2,3...,50이 담긴 배열 생성하기
# np.linspace(1,50,50)

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# 0부터 1 사이의 수를 랜덤하게...
# ![image-3.png](attachment:image-3.png)
# 우리가 지정한 숫자에서 랜덤하게..
# ![image-4.png](attachment:image-4.png)
